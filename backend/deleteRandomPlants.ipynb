# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("plants.csv")

# %%
df_sampled = df.sample(frac=0.01, random_state=np.random.RandomState())

# %%
df_sampled
# Out:
#        symbol synonymSymbol  \
# 75000    RORU           NaN
# 88145   TRCL2           NaN
# 66711   PLAR9         PLPUA
# 54029   MEAL8        PAAL23
# 55791   MILI3         OXGA2
# ...       ...           ...
# 79782   SECO4        CHHI10
# 56432   MOCO7         LECO9
# 34523  EUCO10         EUCOA
# 24106    CRUN         CRCH2
# 70788    PSFA           NaN
#
#                                 scientificNameWithAuthor  \
# 75000                                 Rosa rugosa Thunb.
# 88145                             Trifolium clypeatum L.
# 66711  Plantago purshii Roem. & Schult. var. argyraea...
# 54029                            Parmelia albertana Ahti
# 55791            Oxybaphus gausapoides (Standl.) Standl.
# ...                                                  ...
# 79782                Chaetochloa hispida Scribn. & Merr.
# 56432               Lembertia congdonii (A. Gray) Greene
# 34523   Euphorbia corollata L. var. angustifolia Elliott
# ...

# %%
df_sampled.to_csv("lessPlants.csv")
